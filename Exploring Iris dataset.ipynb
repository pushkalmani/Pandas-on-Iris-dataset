# %% [markdown]
# # Exploring Iris dataset

# %%
# Importing the library
import pandas as pd

# %%
# Loading the dataset
df = pd.read_csv('Iris.csv')

# %%
# Printing the whole dataset
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# 5              5.4           3.9            1.7           0.4     Iris-setosa
# 6              4.6           3.4            1.4           0.3     Iris-setosa
# 7              5.0           3.4            1.5           0.2     Iris-setosa
# 8              4.4           2.9            1.4           0.2     Iris-setosa
# 9              4.9           3.1            1.5           0.1     Iris-setosa
# 10             5.4           3.7            1.5           0.2     Iris-setosa
# ...

# %%
# Printing first five rows
df.head(6)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa
# 5            5.4           3.9            1.7           0.4  Iris-setosa

# %%
# Printing last three rows
df.tail(3)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica

# %%
# (rows, columns)
df.shape
# Out:
# (150, 5)

# %%
rows, columns = df.shape

# %%
rows
# Out:
# 150

# %%
columns
# Out:
# 5

# %%
# Information about range of index 
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
# Name of columns
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
# Statistical values for numerical features
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df['SepalLengthCm'].count()
# Out:
# 150

# %%
df['SepalLengthCm'].mean()
# Out:
# 5.843333333333335

# %%
df['SepalLengthCm'].std() # Standard deviation
# Out:
# 0.8280661279778629

# %%
df['SepalLengthCm'].min()
# Out:
# 4.3

# %%
df['SepalLengthCm'].max()
# Out:
# 7.9

# %%
df.sum()
# Out:
# SepalLengthCm                                                876.5
# SepalWidthCm                                                 458.1
# PetalLengthCm                                                563.8
# PetalWidthCm                                                 179.8
# Species          Iris-setosaIris-setosaIris-setosaIris-setosaIr...
# dtype: object

# %%
df.cumsum()
# Out:
#     SepalLengthCm SepalWidthCm PetalLengthCm PetalWidthCm  \
# 0             5.1          3.5           1.4          0.2
# 1              10          6.5           2.8          0.4
# 2            14.7          9.7           4.1          0.6
# 3            19.3         12.8           5.6          0.8
# 4            24.3         16.4             7            1
# 5            29.7         20.3           8.7          1.4
# 6            34.3         23.7          10.1          1.7
# 7            39.3         27.1          11.6          1.9
# 8            43.7           30            13          2.1
# 9            48.6         33.1          14.5          2.2
# 10             54         36.8            16          2.4
# 11           58.8         40.2          17.6          2.6
# 12           63.6         43.2            19          2.7
# 13           67.9         46.2          20.1          2.8
# 14           73.7         50.2          21.3            3
# ...

# %%
# Data type of whole dataset
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Data type of column in a dataset
type(df['SepalLengthCm'])
# Out:
# pandas.core.series.Series

# %%
# Separating specific columns from whole dataset
# Separating sepal information from whole dataset
df[['SepalLengthCm','SepalWidthCm']]
# Out:
#      SepalLengthCm  SepalWidthCm
# 0              5.1           3.5
# 1              4.9           3.0
# 2              4.7           3.2
# 3              4.6           3.1
# 4              5.0           3.6
# 5              5.4           3.9
# 6              4.6           3.4
# 7              5.0           3.4
# 8              4.4           2.9
# 9              4.9           3.1
# 10             5.4           3.7
# 11             4.8           3.4
# 12             4.8           3.0
# 13             4.3           3.0
# 14             5.8           4.0
# 15             5.7           4.4
# 16             5.4           3.9
# 17             5.1           3.5
# 18             5.7           3.8
# 19             5.1           3.8
# 20             5.4           3.4
# 21             5.1           3.7
# 22             4.6           3.6
# 23             5.1           3.3
# 24             4.8           3.4
# 25             5.0           3.0
# 26             5.0           3.4
# ...

# %%
# Separating petal information from whole dataset
df[['PetalLengthCm','PetalWidthCm']]
# Out:
#      PetalLengthCm  PetalWidthCm
# 0              1.4           0.2
# 1              1.4           0.2
# 2              1.3           0.2
# 3              1.5           0.2
# 4              1.4           0.2
# 5              1.7           0.4
# 6              1.4           0.3
# 7              1.5           0.2
# 8              1.4           0.2
# 9              1.5           0.1
# 10             1.5           0.2
# 11             1.6           0.2
# 12             1.4           0.1
# 13             1.1           0.1
# 14             1.2           0.2
# 15             1.5           0.4
# 16             1.3           0.4
# 17             1.4           0.3
# 18             1.7           0.3
# 19             1.5           0.3
# 20             1.7           0.2
# 21             1.5           0.4
# 22             1.0           0.2
# 23             1.7           0.5
# 24             1.9           0.2
# 25             1.6           0.2
# 26             1.6           0.4
# ...

# %%
# Printing specific columns with all rows
df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm','PetalWidthCm']]
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# 5              5.4           3.9            1.7           0.4
# 6              4.6           3.4            1.4           0.3
# 7              5.0           3.4            1.5           0.2
# 8              4.4           2.9            1.4           0.2
# 9              4.9           3.1            1.5           0.1
# 10             5.4           3.7            1.5           0.2
# 11             4.8           3.4            1.6           0.2
# 12             4.8           3.0            1.4           0.1
# 13             4.3           3.0            1.1           0.1
# ...

# %%
# Printing specific column with all rows
df[['Species']].head(15)
# Out:
#         Species
# 0   Iris-setosa
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# 4   Iris-setosa
# 5   Iris-setosa
# 6   Iris-setosa
# 7   Iris-setosa
# 8   Iris-setosa
# 9   Iris-setosa
# 10  Iris-setosa
# 11  Iris-setosa
# 12  Iris-setosa
# 13  Iris-setosa
# 14  Iris-setosa

# %%
# iloc - Selection by position

# %%
# Printing specific row and specific column

df.iloc[[0], [0]]
# Out:
#    SepalLengthCm
# 0            5.1

# %%
# Printing specific rows with specific columns
X = df.iloc[:, :-1]

# %%
X
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# 5              5.4           3.9            1.7           0.4
# 6              4.6           3.4            1.4           0.3
# 7              5.0           3.4            1.5           0.2
# 8              4.4           2.9            1.4           0.2
# 9              4.9           3.1            1.5           0.1
# 10             5.4           3.7            1.5           0.2
# 11             4.8           3.4            1.6           0.2
# 12             4.8           3.0            1.4           0.1
# 13             4.3           3.0            1.1           0.1
# ...

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
# Printing specific rows with specific columns
y = df.iloc[:, -1:]

# %%
y
# Out:
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# 6       Iris-setosa
# 7       Iris-setosa
# 8       Iris-setosa
# 9       Iris-setosa
# 10      Iris-setosa
# 11      Iris-setosa
# 12      Iris-setosa
# 13      Iris-setosa
# 14      Iris-setosa
# 15      Iris-setosa
# 16      Iris-setosa
# 17      Iris-setosa
# 18      Iris-setosa
# 19      Iris-setosa
# 20      Iris-setosa
# 21      Iris-setosa
# 22      Iris-setosa
# 23      Iris-setosa
# 24      Iris-setosa
# 25      Iris-setosa
# 26      Iris-setosa
# 27      Iris-setosa
# 28      Iris-setosa
# 29      Iris-setosa
# ..              ...
# 120  Iris-virginica
# 121  Iris-virginica
# 122  Iris-virginica
# 123  Iris-virginica
# 124  Iris-virginica
# 125  Iris-virginica
# 126  Iris-virginica
# 127  Iris-virginica
# 128  Iris-virginica
# 129  Iris-virginica
# 130  Iris-virginica
# 131  Iris-virginica
# 132  Iris-virginica
# ...

# %%
type(y)
# Out:
# pandas.core.frame.DataFrame

# %%
# Printing specific rows with specific columns
df.iloc[[0,2,4,6], [0,2]]
# Out:
#    SepalLengthCm  PetalLengthCm
# 0            5.1            1.4
# 2            4.7            1.3
# 4            5.0            1.4
# 6            4.6            1.4

# %%
# Printing specific rows with specific columns
df.iloc[0:4, [0,2]]
# Out:
#    SepalLengthCm  PetalLengthCm
# 0            5.1            1.4
# 1            4.9            1.4
# 2            4.7            1.3
# 3            4.6            1.5

# %%
# Printing specific rows with specific columns
df.iloc[[0,2], 0:4]
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 2            4.7           3.2            1.3           0.2

# %%
# Printing specific rows with specific columns
df.iloc[0:4, 0:2]
# Out:
#    SepalLengthCm  SepalWidthCm
# 0            5.1           3.5
# 1            4.9           3.0
# 2            4.7           3.2
# 3            4.6           3.1

# %%
# loc - Selection by label

# %%
# Printing specific row and specific column
df.loc[[0], ['SepalLengthCm']]
# Out:
#    SepalLengthCm
# 0            5.1

# %%
# Printing specific row with all columns
df.loc[[0]]
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa

# %%
# Printing specific rows with specific columns
df.loc[[0,2,4,6], ['SepalLengthCm','PetalLengthCm']]
# Out:
#    SepalLengthCm  PetalLengthCm
# 0            5.1            1.4
# 2            4.7            1.3
# 4            5.0            1.4
# 6            4.6            1.4

# %%
# Printing specific rows with specific columns
df.loc[2:6][['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm','PetalWidthCm']]
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2
# 5            5.4           3.9            1.7           0.4
# 6            4.6           3.4            1.4           0.3

# %%
df[df.SepalLengthCm >= 7] # Comparing a feature
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 50             7.0           3.2            4.7           1.4  Iris-versicolor
# 102            7.1           3.0            5.9           2.1   Iris-virginica
# 105            7.6           3.0            6.6           2.1   Iris-virginica
# 107            7.3           2.9            6.3           1.8   Iris-virginica
# 109            7.2           3.6            6.1           2.5   Iris-virginica
# 117            7.7           3.8            6.7           2.2   Iris-virginica
# 118            7.7           2.6            6.9           2.3   Iris-virginica
# 122            7.7           2.8            6.7           2.0   Iris-virginica
# 125            7.2           3.2            6.0           1.8   Iris-virginica
# 129            7.2           3.0            5.8           1.6   Iris-virginica
# 130            7.4           2.8            6.1           1.9   Iris-virginica
# ...

# %%
df[df.SepalLengthCm == df.SepalLengthCm .max()]
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 131            7.9           3.8            6.4           2.0  Iris-virginica

# %%
df[['SepalLengthCm', 'Species']][df.SepalLengthCm == df.SepalLengthCm .max()]
# Out:
#      SepalLengthCm         Species
# 131            7.9  Iris-virginica

# %%
df[df.SepalWidthCm <= 2]
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 60            5.0           2.0            3.5           1.0  Iris-versicolor

# %%
# Correlation between values
df.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
# Predictor variables
X = df.iloc[:, :-1].values

# %%
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
# Target variable
y = df.iloc[:, -1:].values

# %%
y
# Out:
# array([['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
# ...

# %%
type(X)
# Out:
# numpy.ndarray

# %%
type(y)
# Out:
# numpy.ndarray

# %%
# Importing data visualizaton libraries
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.corr()) # Pictorial representation of correlation
plt.show()
